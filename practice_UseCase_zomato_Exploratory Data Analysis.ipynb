# %%
pwd
# Out:
# 'C:\\Users\\admin'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
zomato_orignal=pd.read_csv("zomato.csv")

# %%
zomato_orignal.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
zomato_orignal.shape
# Out:
# (51717, 17)

# %%
zozomato_orignal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %%
zomato_orignal.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
zomato_copy=zomato_orignal.copy()

# %%
zomato1=zomato_orignal.drop(['url','phone','dish_liked'],axis=1)

# %%
zomato1.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'location', 'rest_type', 'cuisines', 'approx_cost(for two people)',
#        'reviews_list', 'menu_item', 'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
zomato1.shape
# Out:
# (51717, 14)

# %%
zomato1
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# ...

# %%
zomato1.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51712    False
# 51713    False
# 51714    False
# 51715    False
# 51716    False
# Length: 51717, dtype: bool

# %%
zomato1.duplicated().sum()
# Out:
# 43

# %%
zomato1.drop_duplicates(inplace=True)

# %%
zomato1
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# ...

# %%
zomato1.shape
# Out:
# (51674, 14)

# %%
zomato1.isna()
# Out:
#        address   name  online_order  book_table   rate  votes  location  \
# 0        False  False         False       False  False  False     False
# 1        False  False         False       False  False  False     False
# 2        False  False         False       False  False  False     False
# 3        False  False         False       False  False  False     False
# 4        False  False         False       False  False  False     False
# ...        ...    ...           ...         ...    ...    ...       ...
# 51712    False  False         False       False  False  False     False
# 51713    False  False         False       False   True  False     False
# 51714    False  False         False       False   True  False     False
# 51715    False  False         False       False  False  False     False
# 51716    False  False         False       False  False  False     False
#
#        rest_type  cuisines  approx_cost(for two people)  reviews_list  \
# ...

# %%
zomato1.isnull()
# Out:
#        address   name  online_order  book_table   rate  votes  location  \
# 0        False  False         False       False  False  False     False
# 1        False  False         False       False  False  False     False
# 2        False  False         False       False  False  False     False
# 3        False  False         False       False  False  False     False
# 4        False  False         False       False  False  False     False
# ...        ...    ...           ...         ...    ...    ...       ...
# 51712    False  False         False       False  False  False     False
# 51713    False  False         False       False   True  False     False
# 51714    False  False         False       False   True  False     False
# 51715    False  False         False       False  False  False     False
# 51716    False  False         False       False  False  False     False
#
#        rest_type  cuisines  approx_cost(for two people)  reviews_list  \
# ...

# %%
zomato1.isnull().sum()
# Out:
# address                           0
# name                              0
# online_order                      0
# book_table                        0
# rate                           7767
# votes                             0
# location                         21
# rest_type                       227
# cuisines                         45
# approx_cost(for two people)     345
# reviews_list                      0
# menu_item                         0
# listed_in(type)                   0
# listed_in(city)                   0
# dtype: int64

# %%
zomato1.isna().sum()
# Out:
# address                           0
# name                              0
# online_order                      0
# book_table                        0
# rate                           7767
# votes                             0
# location                         21
# rest_type                       227
# cuisines                         45
# approx_cost(for two people)     345
# reviews_list                      0
# menu_item                         0
# listed_in(type)                   0
# listed_in(city)                   0
# dtype: int64

# %%
zomato1.dropna(how='any')
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51709  136, SAP Labs India, KIADB Export Promotion In...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# ...

# %%
zomato1.shape
# Out:
# (51674, 14)

# %%
zomato1.dropna(how='any',inplace=True)

# %%
zomato1.shape
# Out:
# (43499, 14)

# %%
zomato1.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'location', 'rest_type', 'cuisines', 'approx_cost(for two people)',
#        'reviews_list', 'menu_item', 'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
zomato2=zomato1.rename({'approx_cost(for two people)':'cost','rate':'rating','reviews_list':'review'},axis=1)

# %%
zomato2.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rating', 'votes',
#        'location', 'rest_type', 'cuisines', 'cost', 'review', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
zomato2=zomato1.rename(columns={'approx_cost(for two people)':'cost','rate':'rating','reviews_list':'review'})

# %%
zomato2.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rating', 'votes',
#        'location', 'rest_type', 'cuisines', 'cost', 'review', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %% [markdown]
# # Transformations

# %%
zomato2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43499 entries, 0 to 51716
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   address          43499 non-null  object
#  1   name             43499 non-null  object
#  2   online_order     43499 non-null  object
#  3   book_table       43499 non-null  object
#  4   rating           43499 non-null  object
#  5   votes            43499 non-null  int64
#  6   location         43499 non-null  object
#  7   rest_type        43499 non-null  object
#  8   cuisines         43499 non-null  object
#  9   cost             43499 non-null  object
#  10  review           43499 non-null  object
#  11  menu_item        43499 non-null  object
#  12  listed_in(type)  43499 non-null  object
#  13  listed_in(city)  43499 non-null  object
# dtypes: int64(1), object(13)
# memory usage: 5.0+ MB

# %%
zomato2['cost']
# Out:
# 0          800
# 1          800
# 2          800
# 3          300
# 4          600
#          ...
# 51709      800
# 51711      800
# 51712    1,500
# 51715    2,500
# 51716    1,500
# Name: cost, Length: 43499, dtype: object

# %%
zomato2['cost']=zomato2['cost'].astype(str)

# %%
lambda i:i.replace(",",".")
# Out:
# <function __main__.<lambda>(i)>

# %%
zomato2["cost"]=zomato2["cost"].apply(lambda i:i.replace(",","."))

# %%
zomato2['cost']
# Out:
# 0          800
# 1          800
# 2          800
# 3          300
# 4          600
#          ...
# 51709      800
# 51711      800
# 51712    1.500
# 51715    2.500
# 51716    1.500
# Name: cost, Length: 43499, dtype: object

# %%
zomato2['cost']=zomato2['cost'].astype(float)

# %%
type(zomato2['cost'])
# Out:
# pandas.core.series.Series

# %%
zomato2['cost']
# Out:
# 0        800.0
# 1        800.0
# 2        800.0
# 3        300.0
# 4        600.0
#          ...
# 51709    800.0
# 51711    800.0
# 51712      1.5
# 51715      2.5
# 51716      1.5
# Name: cost, Length: 43499, dtype: float64

# %%
zomato2['rating'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', 'NEW', '2.9/5', '3.5/5', '2.6/5', '3.8 /5', '3.4/5',
#        '4.5/5', '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5',
#        '3.4 /5', '-', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5',
#        '4.1 /5', '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5',
#        '3.5 /5', '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5',
#        '4.3 /5', '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5',
#        '4.9 /5', '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5',
#        '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
zomato2['rating'].nunique()
# Out:
# 64

# %%
zomato3=zomato2.loc[zomato2['rating']!='NEW']

# %%
zomato3['rating'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', '2.9/5', '3.5/5', '2.6/5', '3.8 /5', '3.4/5', '4.5/5',
#        '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5', '3.4 /5',
#        '-', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5', '4.1 /5',
#        '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5', '3.5 /5',
#        '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5', '4.3 /5',
#        '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5', '4.9 /5',
#        '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5', '2.1 /5',
#        '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
zomato4=zomato3.loc[zomato3['rating']!='-']

# %%
zomato4['rating']
# Out:
# 0         4.1/5
# 1         4.1/5
# 2         3.8/5
# 3         3.7/5
# 4         3.8/5
#           ...
# 51709    3.7 /5
# 51711    2.5 /5
# 51712    3.6 /5
# 51715    4.3 /5
# 51716    3.4 /5
# Name: rating, Length: 41237, dtype: object

# %%
zomato4
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51709  136, SAP Labs India, KIADB Export Promotion In...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# ...

# %%
zomato4.shape
# Out:
# (41237, 14)

# %%
zomato4['rating'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', '2.9/5', '3.5/5', '2.6/5', '3.8 /5', '3.4/5', '4.5/5',
#        '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5', '3.4 /5',
#        '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5', '4.1 /5',
#        '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5', '3.5 /5',
#        '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5', '4.3 /5',
#        '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5', '4.9 /5',
#        '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5', '2.1 /5',
#        '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %% [markdown]
# # DAY 2

# %%
lambda i:i.replace('/5','') if type(i)==np.str else i
# Out:
# <function __main__.<lambda>(i)>

# %%
remove_slash= lambda i:i.replace('/5','') if type(i)==np.str else i

# %%
zomato4['rating']=zomato4['rating'].apply(remove_slash).str.strip().astype(float)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_7512\3984451225.py:1: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   remove_slash= lambda i:i.replace('/5','') if type(i)==np.str else i
# C:\Users\admin\AppData\Local\Temp\ipykernel_7512\1209336833.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zomato4['rating']=zomato4['rating'].apply(remove_slash).str.strip().astype(float)

# %%
zomato4['rating'].unique()
# Out:
# array([4.1, 3.8, 3.7, 3.6, 4.6, 4. , 4.2, 3.9, 3.1, 3. , 3.2, 3.3, 2.8,
#        4.4, 4.3, 2.9, 3.5, 2.6, 3.4, 4.5, 2.5, 2.7, 4.7, 2.4, 2.2, 2.3,
#        4.8, 4.9, 2.1, 2. , 1.8])

# %%
zomato4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41237 entries, 0 to 51716
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   address          41237 non-null  object
#  1   name             41237 non-null  object
#  2   online_order     41237 non-null  object
#  3   book_table       41237 non-null  object
#  4   rating           41237 non-null  float64
#  5   votes            41237 non-null  int64
#  6   location         41237 non-null  object
#  7   rest_type        41237 non-null  object
#  8   cuisines         41237 non-null  object
#  9   cost             41237 non-null  float64
#  10  review           41237 non-null  object
#  11  menu_item        41237 non-null  object
#  12  listed_in(type)  41237 non-null  object
#  13  listed_in(city)  41237 non-null  object
# dtypes: float64(2), int64(1), object(11)
# memory usage: 4.7+ MB

# %%
zomato4.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rating', 'votes',
#        'location', 'rest_type', 'cuisines', 'cost', 'review', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
zomato4['name']
# Out:
# 0                                                    Jalsa
# 1                                           Spice Elephant
# 2                                          San Churro Cafe
# 3                                    Addhuri Udupi Bhojana
# 4                                            Grand Village
#                                ...
# 51709                           The Farm House Bar n Grill
# 51711                                              Bhagini
# 51712    Best Brews - Four Points by Sheraton Bengaluru...
# 51715    Chime - Sheraton Grand Bengaluru Whitefield Ho...
# 51716                         The Nest - The Den Bengaluru
# Name: name, Length: 41237, dtype: object

# %%
zomato4['name']=zomato4['name'].apply(lambda x:x.title())
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_7512\890347988.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zomato4['name']=zomato4['name'].apply(lambda x:x.title())

# %%
zomato4['name']
# Out:
# 0                                                    Jalsa
# 1                                           Spice Elephant
# 2                                          San Churro Cafe
# 3                                    Addhuri Udupi Bhojana
# 4                                            Grand Village
#                                ...
# 51709                           The Farm House Bar N Grill
# 51711                                              Bhagini
# 51712    Best Brews - Four Points By Sheraton Bengaluru...
# 51715    Chime - Sheraton Grand Bengaluru Whitefield Ho...
# 51716                         The Nest - The Den Bengaluru
# Name: name, Length: 41237, dtype: object

# %%
zomato4['online_order']
# Out:
# 0        Yes
# 1        Yes
# 2        Yes
# 3         No
# 4         No
#         ...
# 51709     No
# 51711     No
# 51712     No
# 51715     No
# 51716     No
# Name: online_order, Length: 41237, dtype: object

# %%
zomato4['book_table']
# Out:
# 0        Yes
# 1         No
# 2         No
# 3         No
# 4         No
#         ...
# 51709     No
# 51711     No
# 51712     No
# 51715    Yes
# 51716     No
# Name: book_table, Length: 41237, dtype: object

# %%
zomato4['online_order'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
zomato4['book_table'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
zomato4['online_order'].replace(('Yes', 'No'),(True,False),inplace=True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_7512\1381564029.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zomato4['online_order'].replace(('Yes', 'No'),(True,False),inplace=True)

# %%
zomato4['book_table'].replace(('Yes', 'No'),(True,False),inplace=True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_7512\209168644.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zomato4['book_table'].replace(('Yes', 'No'),(True,False),inplace=True)

# %%
zomato4
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51709  136, SAP Labs India, KIADB Export Promotion In...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name  online_order  \
# 0                                                  Jalsa          True
# 1                                         Spice Elephant          True
# ...

# %%
zomato4.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rating', 'votes',
#        'location', 'rest_type', 'cuisines', 'cost', 'review', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
zomato4['cost'].unique()
# Out:
# array([800.  , 300.  , 600.  , 700.  , 550.  , 500.  , 450.  , 650.  ,
#        400.  , 900.  , 200.  , 750.  , 150.  , 850.  , 100.  ,   1.2 ,
#        350.  , 250.  , 950.  ,   1.  ,   1.5 ,   1.3 , 199.  ,   1.1 ,
#          1.6 , 230.  , 130.  ,   1.7 ,   1.35,   2.2 ,   1.4 ,   2.  ,
#          1.8 ,   1.9 , 180.  , 330.  ,   2.5 ,   2.1 ,   3.  ,   2.8 ,
#          3.4 ,  50.  ,  40.  ,   1.25,   3.5 ,   4.  ,   2.4 ,   2.6 ,
#          1.45,  70.  ,   3.2 , 240.  ,   6.  ,   1.05,   2.3 ,   4.1 ,
#        120.  ,   5.  ,   3.7 ,   1.65,   2.7 ,   4.5 ,  80.  ])

# %% [markdown]
# # Encoding
# Convert String data into numbers

# %%
zomato4['address']
# Out:
# 0        942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1        2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2        1112, Next to KIMS Medical College, 17th Cross...
# 3        1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4        10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
#                                ...
# 51709    136, SAP Labs India, KIADB Export Promotion In...
# 51711    139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51712    Four Points by Sheraton Bengaluru, 43/3, White...
# 51715    Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716    ITPL Main Road, KIADB Export Promotion Industr...
# Name: address, Length: 41237, dtype: object

# %%
zomato4['address'].factorize()
# Out:
# (array([   0,    1,    2, ..., 8725, 8786, 3444], dtype=int64),
#  Index(['942, 21st Main Road, 2nd Stage, Banashankari, Bangalore',
#         '2nd Floor, 80 Feet Road, Near Big Bazaar, 6th Block, Kathriguppe, 3rd Stage, Banashankari, Bangalore',
#         '1112, Next to KIMS Medical College, 17th Cross, 2nd Stage, Banashankari, Bangalore',
#         '1st Floor, Annakuteera, 3rd Stage, Banashankari, Bangalore',
#         '10, 3rd Floor, Lakshmi Associates, Gandhi Bazaar Main Road, Above Reliance Trends, Basavanagudi, Bangalore',
#         '37, 5-1, 4th Floor, Bosco Court, Gandhi Bazaar Main Road, Basavanagudi, Bangalore',
#         '19/1, New Timberyard Layout, Beside Satellite Bus Stop, Mysore Road, Bangalore',
#         '2469, 3rd Floor, 24th Cross, Opposite BDA Complex, 2nd Stage, Banashankari, Bangalore',
#         '1, 30th Main Road, 3rd Stage, Banashankari, Bangalore',
#         '2470, 21 Main Road, 25th Cross, Banashankari, Bangalore',
#         ...
# ...

# %%
zomato4['address']
# Out:
# 0        942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1        2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2        1112, Next to KIMS Medical College, 17th Cross...
# 3        1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4        10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
#                                ...
# 51709    136, SAP Labs India, KIADB Export Promotion In...
# 51711    139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51712    Four Points by Sheraton Bengaluru, 43/3, White...
# 51715    Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716    ITPL Main Road, KIADB Export Promotion Industr...
# Name: address, Length: 41237, dtype: object

# %%
type(zomato4['address'].factorize())
# Out:
# tuple

# %%
zomato4['address'].factorize()[0]
# Out:
# array([   0,    1,    2, ..., 8725, 8786, 3444], dtype=int64)

# %%
zomato4.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rating', 'votes',
#        'location', 'rest_type', 'cuisines', 'cost', 'review', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
def encode_data(z):
    for column in z.columns[~z.columns.isin(['rating','cost','votes'])]:z[column]=z[column].factorize()[0]
    return z

# %%
zomato4_encoded=encode_data(zomato4)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_7512\150597491.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   for column in z.columns[~z.columns.isin(['rating','cost','votes'])]:z[column]=z[column].factorize()[0]

# %%
zomato4_encoded
# Out:
#        address  name  online_order  book_table  rating  votes  location  \
# 0            0     0             0           0     4.1    775         0
# 1            1     1             0           1     4.1    787         0
# 2            2     2             0           1     3.8    918         0
# 3            3     3             1           1     3.7     88         0
# 4            4     4             1           1     3.8    166         1
# ...        ...   ...           ...         ...     ...    ...       ...
# 51709     3137  2699             1           1     3.7     34        25
# 51711     8791  1716             1           1     2.5     81        25
# 51712     8725  6532             1           1     3.6     27        25
# 51715     8786  6568             1           0     4.3    236        56
# 51716     3444  6569             1           1     3.4     13        56
#
#        rest_type  cuisines   cost  review  menu_item  listed_in(type)  \
# ...

# %%
zomato4_encoded.corr()
# Out:
#                   address      name  online_order  book_table    rating  \
# address          1.000000  0.682346      0.165707    0.021447 -0.036195
# name             0.682346  1.000000      0.231616   -0.033718 -0.046936
# online_order     0.165707  0.231616      1.000000   -0.054894 -0.069042
# book_table       0.021447 -0.033718     -0.054894    1.000000 -0.426027
# rating          -0.036195 -0.046936     -0.069042   -0.426027  1.000000
# votes           -0.010738 -0.043871      0.013278   -0.393270  0.435237
# location         0.614626  0.448705      0.048645   -0.032781  0.030363
# rest_type        0.030634  0.036212      0.136741   -0.226763  0.196933
# cuisines         0.238421  0.301793      0.049921   -0.225396  0.189624
# cost             0.003227 -0.084328     -0.180782    0.266651 -0.115346
# review           0.512074  0.339130      0.051440   -0.132809  0.159661
# menu_item        0.058929 -0.031798     -0.362114    0.040496  0.054942
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(zomato4_encoded.corr())
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,8))
sns.heatmap(zomato4_encoded.corr(),annot=True,linewidths=5,cmap='Set1')
# Out:
# <AxesSubplot:>

# %%
zomato4
# Out:
#        address  name  online_order  book_table  rating  votes  location  \
# 0            0     0             0           0     4.1    775         0
# 1            1     1             0           1     4.1    787         0
# 2            2     2             0           1     3.8    918         0
# 3            3     3             1           1     3.7     88         0
# 4            4     4             1           1     3.8    166         1
# ...        ...   ...           ...         ...     ...    ...       ...
# 51709     3137  2699             1           1     3.7     34        25
# 51711     8791  1716             1           1     2.5     81        25
# 51712     8725  6532             1           1     3.6     27        25
# 51715     8786  6568             1           0     4.3    236        56
# 51716     3444  6569             1           1     3.4     13        56
#
#        rest_type  cuisines   cost  review  menu_item  listed_in(type)  \
# ...

# %%
zomato4['rating']=zomato4['rating'].apply(remove_slash).str.strip().astype(float)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_7512\3984451225.py:1: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   remove_slash= lambda i:i.replace('/5','') if type(i)==np.str else i
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [94], in <cell line: 1>()
# ----> 1 zomato4['rating']=zomato4['rating'].apply(remove_slash).str.strip().astype(float)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
# ...

# %%
zomato4=zomato3.loc[zomato3['rating']!='-']

# %%
zomato4['rating']=zomato4['rating'].apply(remove_slash).str.strip().astype(float)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_7512\3984451225.py:1: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   remove_slash= lambda i:i.replace('/5','') if type(i)==np.str else i
# C:\Users\admin\AppData\Local\Temp\ipykernel_7512\1209336833.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zomato4['rating']=zomato4['rating'].apply(remove_slash).str.strip().astype(float)

# %%
zomato4['name']=zomato4['name'].apply(lambda x:x.title())
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_7512\890347988.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zomato4['name']=zomato4['name'].apply(lambda x:x.title())

# %%
zomato4['online_order'].replace(('Yes', 'No'),(True,False),inplace=True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_7512\1381564029.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zomato4['online_order'].replace(('Yes', 'No'),(True,False),inplace=True)

# %%
zomato4['book_table'].replace(('Yes', 'No'),(True,False),inplace=True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_7512\209168644.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zomato4['book_table'].replace(('Yes', 'No'),(True,False),inplace=True)

# %%
zomato4
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51709  136, SAP Labs India, KIADB Export Promotion In...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name  online_order  \
# 0                                                  Jalsa          True
# 1                                         Spice Elephant          True
# ...

# %%
sns.countplot(zomato4['online_order'])
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='online_order', ylabel='count'>

# %%
sns.countplot(zomato4['book_table'])
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='book_table', ylabel='count'>

# %%
pd.crosstab(zomato4['rating'],zomato4['book_table'])
# Out:
# book_table  False  True
# rating
# 1.8             5     0
# 2.0            11     0
# 2.1            24     0
# 2.2            13    13
# 2.3            51     0
# 2.4            66     0
# 2.5            98     2
# 2.6           245     4
# 2.7           299     4
# 2.8           574     6
# 2.9           792     9
# 3.0           981     9
# 3.1          1540    10
# 3.2          1821    23
# 3.3          2267     5
# 3.4          2428    16
# 3.5          2677    86
# 3.6          3214    72
# 3.7          3589   218
# 3.8          3465   351
# 3.9          3398   556
# 4.0          2459   685
# 4.1          1937   988
# 4.2          1204   950
# 4.3           923   759
# 4.4           369   777
# 4.5           233   423
# 4.6           167   133
# 4.7            50   117
# 4.8            23    43
# 4.9            15    40

# %%
type(pd.crosstab(zomato4['rating'],zomato4['book_table']))
# Out:
# pandas.core.frame.DataFrame

# %%
pd.crosstab(zomato4['rating'],zomato4['book_table']).columns
# Out:
# Index([False, True], dtype='object', name='book_table')

# %%
pd.crosstab(zomato4['rating'],zomato4['book_table']).sort_values(by='rating',axis=0,ascending=False)
# Out:
# book_table  False  True
# rating
# 4.9            15    40
# 4.8            23    43
# 4.7            50   117
# 4.6           167   133
# 4.5           233   423
# 4.4           369   777
# 4.3           923   759
# 4.2          1204   950
# 4.1          1937   988
# 4.0          2459   685
# 3.9          3398   556
# 3.8          3465   351
# 3.7          3589   218
# 3.6          3214    72
# 3.5          2677    86
# 3.4          2428    16
# 3.3          2267     5
# 3.2          1821    23
# 3.1          1540    10
# 3.0           981     9
# 2.9           792     9
# 2.8           574     6
# 2.7           299     4
# 2.6           245     4
# 2.5            98     2
# 2.4            66     0
# 2.3            51     0
# 2.2            13    13
# 2.1            24     0
# 2.0            11     0
# 1.8             5     0

# %%
Y=pd.crosstab(zomato4['rating'],zomato4['book_table'])

# %%
Y.sum()
# Out:
# book_table
# False    34938
# True      6299
# dtype: int64

# %%
Y.sum(1)
# Out:
# rating
# 1.8       5
# 2.0      11
# 2.1      24
# 2.2      26
# 2.3      51
# 2.4      66
# 2.5     100
# 2.6     249
# 2.7     303
# 2.8     580
# 2.9     801
# 3.0     990
# 3.1    1550
# 3.2    1844
# 3.3    2272
# 3.4    2444
# 3.5    2763
# 3.6    3286
# 3.7    3807
# 3.8    3816
# 3.9    3954
# 4.0    3144
# 4.1    2925
# 4.2    2154
# 4.3    1682
# 4.4    1146
# 4.5     656
# 4.6     300
# 4.7     167
# 4.8      66
# 4.9      55
# dtype: int64

# %%
Y.sum(1).astype(float)
# Out:
# rating
# 1.8       5.0
# 2.0      11.0
# 2.1      24.0
# 2.2      26.0
# 2.3      51.0
# 2.4      66.0
# 2.5     100.0
# 2.6     249.0
# 2.7     303.0
# 2.8     580.0
# 2.9     801.0
# 3.0     990.0
# 3.1    1550.0
# 3.2    1844.0
# 3.3    2272.0
# 3.4    2444.0
# 3.5    2763.0
# 3.6    3286.0
# 3.7    3807.0
# 3.8    3816.0
# 3.9    3954.0
# 4.0    3144.0
# 4.1    2925.0
# 4.2    2154.0
# 4.3    1682.0
# 4.4    1146.0
# 4.5     656.0
# 4.6     300.0
# 4.7     167.0
# 4.8      66.0
# 4.9      55.0
# dtype: float64

# %%
Y.div(Y.sum(1).astype(float),axis=0)
# Out:
# book_table     False      True
# rating
# 1.8         1.000000  0.000000
# 2.0         1.000000  0.000000
# 2.1         1.000000  0.000000
# 2.2         0.500000  0.500000
# 2.3         1.000000  0.000000
# 2.4         1.000000  0.000000
# 2.5         0.980000  0.020000
# 2.6         0.983936  0.016064
# 2.7         0.986799  0.013201
# 2.8         0.989655  0.010345
# 2.9         0.988764  0.011236
# 3.0         0.990909  0.009091
# 3.1         0.993548  0.006452
# 3.2         0.987527  0.012473
# 3.3         0.997799  0.002201
# 3.4         0.993453  0.006547
# 3.5         0.968874  0.031126
# 3.6         0.978089  0.021911
# 3.7         0.942737  0.057263
# 3.8         0.908019  0.091981
# 3.9         0.859383  0.140617
# 4.0         0.782125  0.217875
# 4.1         0.662222  0.337778
# 4.2         0.558960  0.441040
# 4.3         0.548751  0.451249
# 4.4         0.321990  0.678010
# 4.5         0.355183  0.644817
# 4.6         0.556667  0.443333
# 4.7         0.299401  0.700599
# ...

# %%
Y.div(Y.sum(1).astype(float),axis=0).plot()
# Out:
# <AxesSubplot:xlabel='rating'>

# %%
Y.div(Y.sum(1).astype(float),axis=0).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='rating'>

# %%
plt.rcParams['figure.figsize']=(14,10)
Y.div(Y.sum(1).astype(float),axis=0).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='rating'>

# %%
plt.rcParams['figure.figsize']=(14,10)
Y.div(Y.sum(1).astype(float),axis=0).plot(kind='bar',color=['green','red'])
# Out:
# <AxesSubplot:xlabel='rating'>

# %%
plt.rcParams['figure.figsize']=(14,10)
Y.div(Y.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,color=['green','red'])
# Out:
# <AxesSubplot:xlabel='rating'>

# %%
plt.rcParams['figure.figsize']=(14,10)
Y.div(Y.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,color=['green','red'])
plt.title('Table Booking Vs Normal Rating')
# Out:
# Text(0.5, 1.0, 'Table Booking Vs Normal Rating')

# %%
plt.rcParams['figure.figsize']=(14,10)
Y.div(Y.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,color=['green','red'])
plt.title('Table Booking Vs Normal Rating',fontsize=35)
# Out:
# Text(0.5, 1.0, 'Table Booking Vs Normal Rating')

# %%
plt.rcParams['figure.figsize']=(14,10)
Y.div(Y.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,color=['green','red'])
plt.title('Table Booking Vs Normal Rating',fontsize=35,fontweight=40)
# Out:
# Text(0.5, 1.0, 'Table Booking Vs Normal Rating')

# %%
plt.rcParams['figure.figsize']=(14,10)
Y.div(Y.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,color=['green','red'])
plt.title('Table Booking Vs Normal Rating',fontsize=35,fontweight=40)
plt.legend(loc=2)
